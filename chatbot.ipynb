# %%
import openai

# %%
# apikey = "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"

# %%
apikey = "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"

# %%
openai.api_key = apikey

# %%
import os
# Question = input("Enter something: ")
# print("You entered:", Question)
Question = "hello! How r you?"


roboot = openai.Completion.create(
    engine = "text-davinci-003",
    prompt = Question,
    max_tokens = 1024,
    n = 1,
    stop = None,
    remperature = 0.9
)

Answer = roboot.choices[0].text

print(Answer)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/openai/api_requestor.py:755, in APIRequestor._interpret_response_line(self, rbody, rcode, rheaders, stream)
#     754     else:
# --> 755         data = json.loads(rbody)
#     756 except (JSONDecodeError, UnicodeDecodeError) as e:
#
# File ~/anaconda3/lib/python3.11/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File ~/anaconda3/lib/python3.11/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
# ...

# %%
apikey="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"
# apikey = "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"
openai.api_key=apikey

soal="سلام برای مجید تجن جاری یک رزومه بنویس"

robot = openai.Completion.create(
    engine="text-davinci-003",
    prompt = soal,
    max_tokens=1024,
    n=1,
    stop=None,
    temperature=0.9
)
 
javab = robot.choices[0].text

print(javab)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/openai/api_requestor.py:755, in APIRequestor._interpret_response_line(self, rbody, rcode, rheaders, stream)
#     754     else:
# --> 755         data = json.loads(rbody)
#     756 except (JSONDecodeError, UnicodeDecodeError) as e:
#
# File ~/anaconda3/lib/python3.11/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File ~/anaconda3/lib/python3.11/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
# ...
